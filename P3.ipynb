# %% [markdown]
# 1. Greedy Best-First Search (8 Puzzle)

# %%
import heapq

# Display puzzle state
def print_state(state):
    for i in range(0, 9, 3):
        print(state[i], state[i+1], state[i+2])
    print()

# Manhattan Distance Heuristic
def heuristic(state, goal):
    distance = 0
    for num in range(1, 9):
        current = state.index(num)
        target = goal.index(num)

        x1, y1 = current // 3, current % 3
        x2, y2 = target // 3, target % 3

        distance += abs(x1 - x2) + abs(y1 - y2)

    return distance

# Generate next states
def get_neighbors(state):
    neighbors = []
    blank = state.index(0)
    moves = [-3, 3, -1, 1]

    for move in moves:
        new = blank + move

        if new >= 0 and new < 9:
            if blank % 3 == 0 and move == -1:
                continue
            if blank % 3 == 2 and move == 1:
                continue

            temp = list(state)
            temp[blank], temp[new] = temp[new], temp[blank]
            neighbors.append(tuple(temp))

    return neighbors

def greedy(initial, goal):
    queue = []
    heapq.heappush(queue, (heuristic(initial, goal), initial, []))
    visited = set()

    while queue:
        h, state, path = heapq.heappop(queue)

        if state == goal:
            return path + [state]

        if state not in visited:
            visited.add(state)

            for next_state in get_neighbors(state):
                heapq.heappush(
                    queue,
                    (heuristic(next_state, goal), next_state, path + [state])
                )

    return None

initial = (
    1, 2, 3,
    4, 0, 6,
    7, 5, 8
)

goal = (
    1, 2, 3,
    4, 5, 6,
    7, 8, 0
)

print("Initial State:")
print_state(initial)

print("Goal State:")
print_state(goal)

solution = greedy(initial, goal)

print("Solution:")
for step, state in enumerate(solution):
    print("Step", step)
    print_state(state)

print("Goal reached successfully.")
print("Lavkush T048")
# Out:
# Initial State:
# 1 2 3
# 4 0 6
# 7 5 8
#
# Goal State:
# 1 2 3
# 4 5 6
# 7 8 0
#
# Solution:
# Step 0
# 1 2 3
# 4 0 6
# 7 5 8
#
# Step 1
# 1 2 3
# 4 5 6
# 7 0 8
#
# Step 2
# 1 2 3
# 4 5 6
# 7 8 0
#
# Goal reached successfully.
# Lavkush T048

# %% [markdown]
# 2. A* Search (8 Puzzle)

# %%
import heapq

def print_state(state):
    for i in range(0, 9, 3):
        print(state[i], state[i+1], state[i+2])
    print()

def heuristic(state, goal):
    distance = 0
    for num in range(1, 9):
        current = state.index(num)
        target = goal.index(num)

        x1, y1 = current // 3, current % 3
        x2, y2 = target // 3, target % 3

        distance += abs(x1 - x2) + abs(y1 - y2)
    return distance

def get_neighbors(state):
    neighbors = []
    blank = state.index(0)
    moves = [-3, 3, -1, 1]

    for move in moves:
        new = blank + move

        if new >= 0 and new < 9:
            if blank % 3 == 0 and move == -1:
                continue
            if blank % 3 == 2 and move == 1:
                continue

            temp = list(state)
            temp[blank], temp[new] = temp[new], temp[blank]
            neighbors.append(tuple(temp))
    return neighbors

def astar(initial, goal):
    queue = []
    heapq.heappush(queue, (heuristic(initial, goal), 0, initial, []))
    visited = set()

    while queue:
        f, g, state, path = heapq.heappop(queue)

        if state == goal:
            return path + [state]

        if state not in visited:
            visited.add(state)

            for next_state in get_neighbors(state):
                new_g = g + 1
                new_f = new_g + heuristic(next_state, goal)
                heapq.heappush(queue, (new_f, new_g, next_state, path + [state]))

    return None

initial = (
    1,2,3,
    4,0,6,
    7,5,8
)

goal = (
    1,2,3,
    4,5,6,
    7,8,0
)

print("Initial State:")
print_state(initial)

print("Goal State:")
print_state(goal)

solution = astar(initial, goal)

print("Shortest Path using A* Search:")
step = 1
for state in solution[1:]:
    print("Step", step)
    print_state(state)
    step += 1

print("Goal reached successfully.")
print("Total number of moves:", len(solution)-1)
print("Lavkush T048")

# %% [markdown]
# 3. A* Search (Weighted Graph)

# %%
import heapq

graph = {
    'Mumbai': [('Pune', 150), ('Surat', 280)],
    'Pune': [('Mumbai', 150), ('Nashik', 210), ('Hyderabad', 560)],
    'Surat': [('Mumbai', 280), ('Ahmedabad', 270)],
    'Ahmedabad': [('Surat', 270), ('Udaipur', 260)],
    'Udaipur': [('Ahmedabad', 260), ('Jaipur', 395)],
    'Jaipur': [('Udaipur', 395), ('Delhi', 280)],
    'Nashik': [('Pune', 210), ('Indore', 415)],
    'Indore': [('Nashik', 415), ('Bhopal', 195)],
    'Bhopal': [('Indore', 195), ('Delhi', 740)],
    'Hyderabad': [('Pune', 560), ('Nagpur', 500)],
    'Nagpur': [('Hyderabad', 500), ('Delhi', 850)],
    'Delhi': []
}

heuristic = {
    'Mumbai':1150,'Pune':1180,'Surat':940,'Ahmedabad':780,
    'Udaipur':560,'Jaipur':280,'Nashik':1030,'Indore':660,
    'Bhopal':590,'Hyderabad':1260,'Nagpur':840,'Delhi':0
}

def astar(start, goal):
    queue=[]
    heapq.heappush(queue,(heuristic[start],0,start,[start]))
    visited=set()

    while queue:
        f_cost,g_cost,city,path=heapq.heappop(queue)

        if city==goal:
            return g_cost,path

        if city not in visited:
            visited.add(city)

            for neighbor,distance in graph[city]:
                new_g=g_cost+distance
                new_f=new_g+heuristic[neighbor]
                heapq.heappush(queue,(new_f,new_g,neighbor,path+[neighbor]))

    return None,[]

cost,path=astar("Mumbai","Delhi")
print("Shortest Path using A* Search:")
print("Path:"," -> ".join(path))
print("Total Cost:",cost)
print("Lavkush T048")
